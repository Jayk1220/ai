# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:99% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:24pt;}
div.text_cell_render.rendered_html{font-size:20pt;}
div.text_cell_render ul li, code{font-size:22pt; line-height:30px;}
div.output {font-size:24pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:24pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:24pt;padding:5px;}
table.dataframe{font-size:24px;}
</style>
"""))
# Out:
# <style>
# div.container{width:99% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:24pt;}
# div.text_cell_render.rendered_html{font-size:20pt;}
# div.text_cell_render ul li, code{font-size:22pt; line-height:30px;}
# div.output {font-size:24pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:24pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:24pt;padding:5px;}
# table.dataframe{font-size:24px;}
# </style>

# %%
import os # 모델 저장할 폴더가 있는지 여부와 폴더 생성
import numpy as np
import pandas as pd # get_dummies(원핫인코딩), crosstab
import seaborn as sns # iris 데이터(데이터프레임) 가져오기
from sklearn import datasets # iris 데이터(X, y) 가져오기
from sklearn.preprocessing import LabelEncoder # 라벨인코더
from tensorflow.keras.utils import to_categorical # 원핫인코딩 
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential, save_model, load_model
from tensorflow.keras.layers import Input, Dense, Dropout, LeakyReLU
from tensorflow.keras import metrics # compile
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt

# %% [markdown]
# - 데이터 셋 생성(seaborn) & 전처리
#     X, y(setosa,versicolor,virginica라벨인코딩-원핫코딩)분리 -> train과 test셋 분리(8:2)
# - 모델 구성(입력4 -> 출력3, layer5: 4->64->128->50->30->3)
# - 모델 학습과정 설정
# - 모델 학습(Earlystopping, ModelCheckpoint추가)
# - 모델평가(시각화, 현재모델과 저장된 최고의 모델 평가, 교차표==혼동행렬)
# - 모델예측/저장

# %% [markdown]
# # 1. 데이터 셋 생성(seaborn) & 전처리

# %%
iris = sns.load_dataset('iris')
iris.loc[::50]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 0             5.1          3.5           1.4          0.2      setosa
# 50            7.0          3.2           4.7          1.4  versicolor
# 100           6.3          3.3           6.0          2.5   virginica

# %%
# 문자변수 원핫인코딩 방법1
encoder = LabelEncoder()
iris['y'] = encoder.fit_transform(iris['species'])
display(iris.loc[::50])
# utils.to_categorical(iris['species'])[:5]
# to_categorical을 하려면 숫자필드로 라벨인코딩먼저
to_categorical(iris['y'])[::50]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species  y
# 0             5.1          3.5           1.4          0.2      setosa  0
# 50            7.0          3.2           4.7          1.4  versicolor  1
# 100           6.3          3.3           6.0          2.5   virginica  2
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]], dtype=float32)

# %%
# 문자변수 원핫인코딩 방법2
pd.get_dummies(iris.species)[::50]
# Out:
#      setosa  versicolor  virginica
# 0         1           0          0
# 50        0           1          0
# 100       0           0          1

# %%
# 1. 데이터 생성 및 전처리
iris = sns.load_dataset('iris')
# 독립변수와 종속변수 분리
iris_X = iris.iloc[:, :-1].to_numpy()
iris_y = iris.iloc[:, -1]
iris_Y = pd.get_dummies(iris_y).values
# 훈련셋 : 테스트셋 = 8 : 2
X_train, X_test, Y_train, Y_test = train_test_split(iris_X, iris_Y,
                                                   test_size=0.2,
                                                   stratify=iris_Y, # 층화추출
                                                   random_state=4) 
X_train.shape, Y_train.shape, X_test.shape, Y_test.shape
# Out:
# ((120, 4), (120, 3), (30, 4), (30, 3))

# %%
# 층화 추출했는지 확인 
pd.Series(np.argmax(Y_train, axis=1)).value_counts()
# Out:
# 0    40
# 1    40
# 2    40
# dtype: int64

# %%
pd.Series(np.argmax(Y_test, axis=1)).value_counts()
# Out:
# 1    10
# 2    10
# 0    10
# dtype: int64

# %% [markdown]
# # 2. 모델 구성
# (입력4 -> 출력3, layer5: 4->64->128->50->30->3)

# %%
model = Sequential()
model.add(Dense(units=64, input_dim=4, activation='relu'))
model.add(Dense(units=128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(units=50, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(units=30, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(units=3, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                320
#
#  dense_1 (Dense)             (None, 128)               8320
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_2 (Dense)             (None, 50)                6450
#
#  dropout_1 (Dropout)         (None, 50)                0
#
#  dense_3 (Dense)             (None, 30)                1530
#
#  dropout_2 (Dropout)         (None, 30)                0
#
#  dense_4 (Dense)             (None, 3)                 93
#
# =================================================================
# Total params: 16,713
# Trainable params: 16,713
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 3. 모델 학습과정 설정

# %%
model.compile(loss='categorical_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])

# %% [markdown]
# # 4. 모델 학습
# (Earlystopping, ModelCheckpoint추가)

# %%
model_save_folder = './model/'
import os
if not os.path.exists(model_save_folder): # 폴더 없으면 폴더 생성
    os.mkdir(model_save_folder)
file = model_save_folder \
        + 'iris-{epoch:03d}-loss{val_loss:.4f}-acc{val_accuracy:.4f}.h5'
# 콜백객체
checkpoint = ModelCheckpoint(
                    filepath=file,
                    monitor='val_accuracy', # 모니터링 지표:loss, val_loss, accuracy
                    save_best_only=True,    # 모니터링 지표가 개선된 경우만 저장
                    mode = 'max',
                    verbose=1) # 로그 출력 여부
earlystopping = EarlyStopping(patience=40)# monitor='val_loss' 기본값
hist=model.fit(X_train,Y_train,batch_size=40,
               epochs=200,
               validation_split=0.2,
               callbacks=[checkpoint,earlystopping])
# Out:
# Epoch 1/200
# 1/3 [=========>....................] - ETA: 0s - loss: 1.2769 - accuracy: 0.1750
# Epoch 1: val_accuracy improved from -inf to 0.70833, saving model to ./model\iris-001-loss1.0326-acc0.7083.h5
# 3/3 [==============================] - 0s 55ms/step - loss: 1.1720 - accuracy: 0.3646 - val_loss: 1.0326 - val_accuracy: 0.7083
# Epoch 2/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.9838 - accuracy: 0.5500
# Epoch 2: val_accuracy improved from 0.70833 to 0.75000, saving model to ./model\iris-002-loss0.9989-acc0.7500.h5
# 3/3 [==============================] - 0s 13ms/step - loss: 1.0471 - accuracy: 0.4896 - val_loss: 0.9989 - val_accuracy: 0.7500
# Epoch 3/200
# 1/3 [=========>....................] - ETA: 0s - loss: 1.0597 - accuracy: 0.5250
# Epoch 3: val_accuracy did not improve from 0.75000
# 3/3 [==============================] - 0s 8ms/step - loss: 1.0365 - accuracy: 0.4792 - val_loss: 0.9675 - val_accuracy: 0.5833
# Epoch 4/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.9045 - accuracy: 0.7750
# Epoch 4: val_accuracy did not improve from 0.75000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.9402 - accuracy: 0.7083 - val_loss: 0.9166 - val_accuracy: 0.5833
# Epoch 5/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.9777 - accuracy: 0.5750
# Epoch 5: val_accuracy did not improve from 0.75000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.9663 - accuracy: 0.5729 - val_loss: 0.8360 - val_accuracy: 0.5833
# Epoch 6/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.8016 - accuracy: 0.8250
# Epoch 6: val_accuracy improved from 0.75000 to 1.00000, saving model to ./model\iris-006-loss0.7437-acc1.0000.h5
# 3/3 [==============================] - 0s 12ms/step - loss: 0.8704 - accuracy: 0.7083 - val_loss: 0.7437 - val_accuracy: 1.0000
# Epoch 7/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.9033 - accuracy: 0.5500
# Epoch 7: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 9ms/step - loss: 0.8239 - accuracy: 0.6354 - val_loss: 0.6677 - val_accuracy: 0.7500
# Epoch 8/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.8079 - accuracy: 0.7000
# Epoch 8: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.7747 - accuracy: 0.6667 - val_loss: 0.6103 - val_accuracy: 0.7500
# Epoch 9/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.7320 - accuracy: 0.7000
# Epoch 9: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.7363 - accuracy: 0.6667 - val_loss: 0.5649 - val_accuracy: 0.7500
# Epoch 10/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.6408 - accuracy: 0.7000
# Epoch 10: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 9ms/step - loss: 0.6862 - accuracy: 0.6250 - val_loss: 0.5286 - val_accuracy: 0.7917
# Epoch 11/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.6841 - accuracy: 0.6250
# Epoch 11: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 9ms/step - loss: 0.6810 - accuracy: 0.5938 - val_loss: 0.5255 - val_accuracy: 1.0000
# Epoch 12/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.6563 - accuracy: 0.7250
# Epoch 12: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.6096 - accuracy: 0.7083 - val_loss: 0.5050 - val_accuracy: 0.9583
# Epoch 13/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.5906 - accuracy: 0.7250
# Epoch 13: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 9ms/step - loss: 0.5283 - accuracy: 0.7812 - val_loss: 0.4715 - val_accuracy: 0.9583
# Epoch 14/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.4661 - accuracy: 0.8250
# Epoch 14: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 9ms/step - loss: 0.5542 - accuracy: 0.7396 - val_loss: 0.4292 - val_accuracy: 0.9583
# Epoch 15/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.5286 - accuracy: 0.8000
# Epoch 15: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.5095 - accuracy: 0.8021 - val_loss: 0.3941 - val_accuracy: 0.9583
# Epoch 16/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.4471 - accuracy: 0.8250
# Epoch 16: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.4747 - accuracy: 0.7917 - val_loss: 0.3439 - val_accuracy: 1.0000
# Epoch 17/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.4761 - accuracy: 0.7500
# Epoch 17: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.4506 - accuracy: 0.7917 - val_loss: 0.2981 - val_accuracy: 1.0000
# Epoch 18/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.4331 - accuracy: 0.8250
# Epoch 18: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 10ms/step - loss: 0.4054 - accuracy: 0.8438 - val_loss: 0.2629 - val_accuracy: 1.0000
# Epoch 19/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.4008 - accuracy: 0.8500
# Epoch 19: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 9ms/step - loss: 0.4033 - accuracy: 0.8125 - val_loss: 0.2429 - val_accuracy: 1.0000
# Epoch 20/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.3822 - accuracy: 0.9000
# Epoch 20: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 10ms/step - loss: 0.3355 - accuracy: 0.9167 - val_loss: 0.2330 - val_accuracy: 1.0000
# Epoch 21/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.3263 - accuracy: 0.8750
# Epoch 21: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.3405 - accuracy: 0.8646 - val_loss: 0.2000 - val_accuracy: 1.0000
# Epoch 22/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.3619 - accuracy: 0.8750
# Epoch 22: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.3540 - accuracy: 0.8750 - val_loss: 0.1981 - val_accuracy: 1.0000
# Epoch 23/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.3198 - accuracy: 0.9000
# Epoch 23: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.3225 - accuracy: 0.9062 - val_loss: 0.2113 - val_accuracy: 1.0000
# Epoch 24/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2389 - accuracy: 0.9500
# Epoch 24: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.2612 - accuracy: 0.9375 - val_loss: 0.1610 - val_accuracy: 1.0000
# Epoch 25/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2873 - accuracy: 0.9000
# Epoch 25: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.2717 - accuracy: 0.9167 - val_loss: 0.1244 - val_accuracy: 1.0000
# Epoch 26/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2116 - accuracy: 0.9500
# Epoch 26: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.2645 - accuracy: 0.9062 - val_loss: 0.1219 - val_accuracy: 1.0000
# Epoch 27/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2471 - accuracy: 0.8750
# Epoch 27: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.2048 - accuracy: 0.9271 - val_loss: 0.2071 - val_accuracy: 0.9167
# Epoch 28/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1824 - accuracy: 0.9500
# Epoch 28: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.2179 - accuracy: 0.9271 - val_loss: 0.1249 - val_accuracy: 1.0000
# Epoch 29/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1594 - accuracy: 1.0000
# Epoch 29: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 9ms/step - loss: 0.2064 - accuracy: 0.9479 - val_loss: 0.0779 - val_accuracy: 1.0000
# Epoch 30/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2059 - accuracy: 0.9000
# Epoch 30: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 9ms/step - loss: 0.2163 - accuracy: 0.9062 - val_loss: 0.0682 - val_accuracy: 1.0000
# Epoch 31/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2281 - accuracy: 0.9250
# Epoch 31: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1800 - accuracy: 0.9479 - val_loss: 0.0810 - val_accuracy: 1.0000
# Epoch 32/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2117 - accuracy: 0.9250
# Epoch 32: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.2177 - accuracy: 0.9375 - val_loss: 0.0855 - val_accuracy: 1.0000
# Epoch 33/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1500 - accuracy: 0.9750
# Epoch 33: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1777 - accuracy: 0.9375 - val_loss: 0.0820 - val_accuracy: 1.0000
# Epoch 34/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1089 - accuracy: 0.9500
# Epoch 34: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1808 - accuracy: 0.9479 - val_loss: 0.0859 - val_accuracy: 1.0000
# Epoch 35/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2469 - accuracy: 0.9250
# Epoch 35: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1850 - accuracy: 0.9271 - val_loss: 0.0450 - val_accuracy: 1.0000
# Epoch 36/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2342 - accuracy: 0.9000
# Epoch 36: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.2095 - accuracy: 0.9062 - val_loss: 0.0366 - val_accuracy: 1.0000
# Epoch 37/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0865 - accuracy: 0.9750
# Epoch 37: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 9ms/step - loss: 0.2064 - accuracy: 0.9167 - val_loss: 0.0360 - val_accuracy: 1.0000
# Epoch 38/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2856 - accuracy: 0.9000
# Epoch 38: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1723 - accuracy: 0.9583 - val_loss: 0.0945 - val_accuracy: 1.0000
# Epoch 39/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0769 - accuracy: 1.0000
# Epoch 39: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1393 - accuracy: 0.9688 - val_loss: 0.1101 - val_accuracy: 0.9583
# Epoch 40/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1437 - accuracy: 0.9250
# Epoch 40: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1628 - accuracy: 0.9271 - val_loss: 0.0389 - val_accuracy: 1.0000
# Epoch 41/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1157 - accuracy: 0.9500
# Epoch 41: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1807 - accuracy: 0.9375 - val_loss: 0.0352 - val_accuracy: 1.0000
# Epoch 42/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1432 - accuracy: 0.9000
# Epoch 42: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1455 - accuracy: 0.9375 - val_loss: 0.0440 - val_accuracy: 1.0000
# Epoch 43/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1464 - accuracy: 0.9750
# Epoch 43: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1690 - accuracy: 0.9479 - val_loss: 0.1101 - val_accuracy: 0.9583
# Epoch 44/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2006 - accuracy: 0.9250
# Epoch 44: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 9ms/step - loss: 0.2040 - accuracy: 0.9271 - val_loss: 0.0414 - val_accuracy: 1.0000
# Epoch 45/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1247 - accuracy: 0.9250
# Epoch 45: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1583 - accuracy: 0.9167 - val_loss: 0.0366 - val_accuracy: 1.0000
# Epoch 46/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1993 - accuracy: 0.9250
# Epoch 46: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.2148 - accuracy: 0.9167 - val_loss: 0.0289 - val_accuracy: 1.0000
# Epoch 47/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1633 - accuracy: 0.9500
# Epoch 47: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1374 - accuracy: 0.9583 - val_loss: 0.0688 - val_accuracy: 1.0000
# Epoch 48/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1687 - accuracy: 0.9250
# Epoch 48: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1494 - accuracy: 0.9271 - val_loss: 0.0968 - val_accuracy: 0.9583
# Epoch 49/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1548 - accuracy: 0.9250
# Epoch 49: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1380 - accuracy: 0.9479 - val_loss: 0.0443 - val_accuracy: 1.0000
# Epoch 50/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1043 - accuracy: 0.9500
# Epoch 50: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1244 - accuracy: 0.9583 - val_loss: 0.0209 - val_accuracy: 1.0000
# Epoch 51/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2088 - accuracy: 0.9500
# Epoch 51: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1469 - accuracy: 0.9583 - val_loss: 0.0247 - val_accuracy: 1.0000
# Epoch 52/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1736 - accuracy: 0.9000
# Epoch 52: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1281 - accuracy: 0.9167 - val_loss: 0.0354 - val_accuracy: 1.0000
# Epoch 53/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1159 - accuracy: 0.9750
# Epoch 53: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1102 - accuracy: 0.9792 - val_loss: 0.0317 - val_accuracy: 1.0000
# Epoch 54/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1010 - accuracy: 1.0000
# Epoch 54: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1024 - accuracy: 0.9792 - val_loss: 0.0247 - val_accuracy: 1.0000
# Epoch 55/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1158 - accuracy: 0.9500
# Epoch 55: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1170 - accuracy: 0.9479 - val_loss: 0.0222 - val_accuracy: 1.0000
# Epoch 56/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1049 - accuracy: 0.9500
# Epoch 56: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1657 - accuracy: 0.9167 - val_loss: 0.0175 - val_accuracy: 1.0000
# Epoch 57/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2403 - accuracy: 0.9250
# Epoch 57: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1350 - accuracy: 0.9583 - val_loss: 0.0376 - val_accuracy: 1.0000
# Epoch 58/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1005 - accuracy: 0.9750
# Epoch 58: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1335 - accuracy: 0.9479 - val_loss: 0.0307 - val_accuracy: 1.0000
# Epoch 59/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1696 - accuracy: 0.9250
# Epoch 59: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1318 - accuracy: 0.9479 - val_loss: 0.0168 - val_accuracy: 1.0000
# Epoch 60/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0920 - accuracy: 0.9250
# Epoch 60: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0852 - accuracy: 0.9583 - val_loss: 0.0218 - val_accuracy: 1.0000
# Epoch 61/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0365 - accuracy: 1.0000
# Epoch 61: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0817 - accuracy: 0.9479 - val_loss: 0.0296 - val_accuracy: 1.0000
# Epoch 62/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0470 - accuracy: 1.0000
# Epoch 62: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0809 - accuracy: 0.9688 - val_loss: 0.0212 - val_accuracy: 1.0000
# Epoch 63/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2169 - accuracy: 0.9250
# Epoch 63: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1765 - accuracy: 0.9479 - val_loss: 0.0174 - val_accuracy: 1.0000
# Epoch 64/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1377 - accuracy: 0.9500
# Epoch 64: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0911 - accuracy: 0.9688 - val_loss: 0.0193 - val_accuracy: 1.0000
# Epoch 65/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0934 - accuracy: 0.9750
# Epoch 65: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1024 - accuracy: 0.9583 - val_loss: 0.0247 - val_accuracy: 1.0000
# Epoch 66/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1250 - accuracy: 0.9500
# Epoch 66: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0932 - accuracy: 0.9583 - val_loss: 0.0237 - val_accuracy: 1.0000
# Epoch 67/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0287 - accuracy: 1.0000
# Epoch 67: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0866 - accuracy: 0.9792 - val_loss: 0.0292 - val_accuracy: 1.0000
# Epoch 68/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0677 - accuracy: 0.9750
# Epoch 68: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0995 - accuracy: 0.9688 - val_loss: 0.0868 - val_accuracy: 0.9583
# Epoch 69/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1785 - accuracy: 0.9500
# Epoch 69: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1175 - accuracy: 0.9583 - val_loss: 0.0920 - val_accuracy: 0.9583
# Epoch 70/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0689 - accuracy: 1.0000
# Epoch 70: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0831 - accuracy: 0.9688 - val_loss: 0.0390 - val_accuracy: 1.0000
# Epoch 71/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1440 - accuracy: 0.9500
# Epoch 71: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1219 - accuracy: 0.9479 - val_loss: 0.0162 - val_accuracy: 1.0000
# Epoch 72/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0417 - accuracy: 1.0000
# Epoch 72: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1004 - accuracy: 0.9792 - val_loss: 0.0099 - val_accuracy: 1.0000
# Epoch 73/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1569 - accuracy: 0.9250
# Epoch 73: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0869 - accuracy: 0.9688 - val_loss: 0.0209 - val_accuracy: 1.0000
# Epoch 74/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0736 - accuracy: 1.0000
# Epoch 74: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1215 - accuracy: 0.9479 - val_loss: 0.0403 - val_accuracy: 1.0000
# Epoch 75/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1135 - accuracy: 0.9750
# Epoch 75: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1232 - accuracy: 0.9792 - val_loss: 0.0285 - val_accuracy: 1.0000
# Epoch 76/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1310 - accuracy: 0.9250
# Epoch 76: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1395 - accuracy: 0.9271 - val_loss: 0.0101 - val_accuracy: 1.0000
# Epoch 77/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0473 - accuracy: 1.0000
# Epoch 77: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0986 - accuracy: 0.9688 - val_loss: 0.0078 - val_accuracy: 1.0000
# Epoch 78/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2226 - accuracy: 0.9250
# Epoch 78: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1591 - accuracy: 0.9271 - val_loss: 0.0160 - val_accuracy: 1.0000
# Epoch 79/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1619 - accuracy: 0.9750
# Epoch 79: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1496 - accuracy: 0.9583 - val_loss: 0.1292 - val_accuracy: 0.9167
# Epoch 80/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0970 - accuracy: 0.9250
# Epoch 80: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1297 - accuracy: 0.9271 - val_loss: 0.0337 - val_accuracy: 1.0000
# Epoch 81/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0450 - accuracy: 1.0000
# Epoch 81: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1112 - accuracy: 0.9583 - val_loss: 0.0094 - val_accuracy: 1.0000
# Epoch 82/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2172 - accuracy: 0.9250
# Epoch 82: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1684 - accuracy: 0.9375 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 83/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1449 - accuracy: 0.9750
# Epoch 83: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1386 - accuracy: 0.9583 - val_loss: 0.0285 - val_accuracy: 1.0000
# Epoch 84/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0883 - accuracy: 0.9500
# Epoch 84: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0737 - accuracy: 0.9688 - val_loss: 0.0933 - val_accuracy: 0.9583
# Epoch 85/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2595 - accuracy: 0.9000
# Epoch 85: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1673 - accuracy: 0.9375 - val_loss: 0.0263 - val_accuracy: 1.0000
# Epoch 86/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0584 - accuracy: 0.9750
# Epoch 86: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1126 - accuracy: 0.9583 - val_loss: 0.0109 - val_accuracy: 1.0000
# Epoch 87/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1245 - accuracy: 0.9750
# Epoch 87: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1325 - accuracy: 0.9583 - val_loss: 0.0126 - val_accuracy: 1.0000
# Epoch 88/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1757 - accuracy: 0.9500
# Epoch 88: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1038 - accuracy: 0.9688 - val_loss: 0.0516 - val_accuracy: 1.0000
# Epoch 89/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1280 - accuracy: 0.9500
# Epoch 89: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1203 - accuracy: 0.9583 - val_loss: 0.0945 - val_accuracy: 0.9583
# Epoch 90/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0576 - accuracy: 0.9750
# Epoch 90: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1442 - accuracy: 0.9583 - val_loss: 0.0291 - val_accuracy: 1.0000
# Epoch 91/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0596 - accuracy: 0.9750
# Epoch 91: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0896 - accuracy: 0.9792 - val_loss: 0.0136 - val_accuracy: 1.0000
# Epoch 92/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1486 - accuracy: 0.9250
# Epoch 92: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1061 - accuracy: 0.9583 - val_loss: 0.0127 - val_accuracy: 1.0000
# Epoch 93/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0771 - accuracy: 0.9750
# Epoch 93: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1171 - accuracy: 0.9688 - val_loss: 0.0155 - val_accuracy: 1.0000
# Epoch 94/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0835 - accuracy: 0.9500
# Epoch 94: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0849 - accuracy: 0.9583 - val_loss: 0.0298 - val_accuracy: 1.0000
# Epoch 95/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2184 - accuracy: 0.9250
# Epoch 95: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1145 - accuracy: 0.9688 - val_loss: 0.0457 - val_accuracy: 1.0000
# Epoch 96/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2013 - accuracy: 0.9250
# Epoch 96: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1355 - accuracy: 0.9583 - val_loss: 0.0268 - val_accuracy: 1.0000
# Epoch 97/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1675 - accuracy: 0.9500
# Epoch 97: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1142 - accuracy: 0.9583 - val_loss: 0.0151 - val_accuracy: 1.0000
# Epoch 98/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1494 - accuracy: 0.9500
# Epoch 98: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1081 - accuracy: 0.9583 - val_loss: 0.0103 - val_accuracy: 1.0000
# Epoch 99/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0956 - accuracy: 0.9750
# Epoch 99: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1058 - accuracy: 0.9583 - val_loss: 0.0126 - val_accuracy: 1.0000
# Epoch 100/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1448 - accuracy: 0.9500
# Epoch 100: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1019 - accuracy: 0.9583 - val_loss: 0.0213 - val_accuracy: 1.0000
# Epoch 101/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0838 - accuracy: 0.9750
# Epoch 101: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0688 - accuracy: 0.9792 - val_loss: 0.0200 - val_accuracy: 1.0000
# Epoch 102/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0496 - accuracy: 0.9750
# Epoch 102: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0767 - accuracy: 0.9792 - val_loss: 0.0273 - val_accuracy: 1.0000
# Epoch 103/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1462 - accuracy: 0.9750
# Epoch 103: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1428 - accuracy: 0.9583 - val_loss: 0.0227 - val_accuracy: 1.0000
# Epoch 104/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1186 - accuracy: 0.9500
# Epoch 104: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1009 - accuracy: 0.9479 - val_loss: 0.0132 - val_accuracy: 1.0000
# Epoch 105/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0371 - accuracy: 1.0000
# Epoch 105: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0792 - accuracy: 0.9792 - val_loss: 0.0133 - val_accuracy: 1.0000
# Epoch 106/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1436 - accuracy: 0.9250
# Epoch 106: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0963 - accuracy: 0.9583 - val_loss: 0.0196 - val_accuracy: 1.0000
# Epoch 107/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0873 - accuracy: 0.9500
# Epoch 107: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0827 - accuracy: 0.9583 - val_loss: 0.0215 - val_accuracy: 1.0000
# Epoch 108/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0979 - accuracy: 0.9500
# Epoch 108: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0987 - accuracy: 0.9688 - val_loss: 0.0267 - val_accuracy: 1.0000
# Epoch 109/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1111 - accuracy: 0.9250
# Epoch 109: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1173 - accuracy: 0.9479 - val_loss: 0.0147 - val_accuracy: 1.0000
# Epoch 110/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1504 - accuracy: 0.9500
# Epoch 110: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1110 - accuracy: 0.9688 - val_loss: 0.0116 - val_accuracy: 1.0000
# Epoch 111/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0934 - accuracy: 0.9500
# Epoch 111: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 9ms/step - loss: 0.0814 - accuracy: 0.9583 - val_loss: 0.0183 - val_accuracy: 1.0000
# Epoch 112/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1419 - accuracy: 0.9500
# Epoch 112: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0944 - accuracy: 0.9688 - val_loss: 0.0322 - val_accuracy: 1.0000
# Epoch 113/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0296 - accuracy: 1.0000
# Epoch 113: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.0820 - accuracy: 0.9792 - val_loss: 0.0363 - val_accuracy: 1.0000
# Epoch 114/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1737 - accuracy: 0.9250
# Epoch 114: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1264 - accuracy: 0.9479 - val_loss: 0.0145 - val_accuracy: 1.0000
# Epoch 115/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1142 - accuracy: 0.9500
# Epoch 115: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1331 - accuracy: 0.9583 - val_loss: 0.0083 - val_accuracy: 1.0000
# Epoch 116/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2088 - accuracy: 0.9500
# Epoch 116: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 8ms/step - loss: 0.1395 - accuracy: 0.9688 - val_loss: 0.0134 - val_accuracy: 1.0000
# Epoch 117/200
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2000 - accuracy: 0.9250
# Epoch 117: val_accuracy did not improve from 1.00000
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1008 - accuracy: 0.9688 - val_loss: 0.0340 - val_accuracy: 1.0000

# %% [markdown]
# # 5. 모델 평가
# (시각화, 현재모델과 저장된 최고의 모델 평가, 교차표==혼동행렬)

# %%
# 학습과정 표시하기
import matplotlib.pyplot as plt
fig, loss_ax = plt.subplots(figsize=(10,6))
loss_ax.plot(hist.history['loss'], 'y', label='train_loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val_loss')
acc_ax = loss_ax.twinx() # loss_ax와 x축을 공유하는 acc_ax 생성
acc_ax.plot(hist.history['accuracy'], 'g', label='train_accuracy')
acc_ax.plot(hist.history['val_accuracy'], 'b', label='val_accuracy')
loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuracy')
loss_ax.legend(bbox_to_anchor=(0.955, 0.7))
acc_ax.legend(loc='center right')
plt.show()

# %%
# 모델 평가
loss_and_acc =model.evaluate(X_test, Y_test, verbose=0)
print(f'loss:{loss_and_acc[0]:.4f}, accuracy:{loss_and_acc[1]:.4f}')

# %%
model1 = load_model('model/iris-001-loss1.0326-acc0.7083.h5')
loss_and_acc1 =model1.evaluate(X_test, Y_test, verbose=0)
print(f'loss:{loss_and_acc1[0]:.4f}, accuracy:{loss_and_acc1[1]:.4f}')
# Out:
# loss:1.0582, accuracy:0.6667

# %%
model2 = load_model('model/iris-006-loss0.7437-acc1.0000.h5')
loss_and_acc2 =model2.evaluate(X_test, Y_test, verbose=0)
print(f'loss:{loss_and_acc2[0]:.4f}, accuracy:{loss_and_acc2[1]:.4f}')
# Out:
# loss:0.7490, accuracy:0.9333
